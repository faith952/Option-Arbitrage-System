# %% [markdown]
# # Week 1 Questions
#
# ## 我已经理解的问题
#
# ## 我还不理解的问题
#
# ## 我觉得最重要的三点
#
# ## 我能联系到期货/产业的地方
#
# ## 我想让导师检查的问题

# %% [markdown]
# # 任务清单
# 1. 改名 READING_PALN.md → READING_PLAN.md
# 2.  阅读 Hull：期权市场机制、期权价格性质、期权交易策略
# 3.  阅读《期权入门与精通》：基础概念、权利金、四种头寸
# 4.  阅读 Natenberg：payoff、risk/reward、volatility基础
# 5.   看 Cboe Options 101 / Payout Diagrams
# 6.   看 CME Introduction to Options
# 7.   看 CME YouTube Options on Futures: Introduction to Options
# 8.   搜索并看 1-2 个 B站中文期权基础视频
# 9.   更新 01_option_basic_deep_dive.md
# 10.  更新 01_option_payoff.ipynb 的 Markdown 解释
# 11.  更新 02_option_strategy_deep_dive.md
# 12.  更新 02_option_strategy_payoff.ipynb 的 Markdown 解释
# 13.  新建 docs/week1_questions.md
# 14.  写 300 字总结：期权为什么不是简单看涨看跌工具？
